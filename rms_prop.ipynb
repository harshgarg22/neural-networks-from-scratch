# %% [markdown]
# # Root Mean Square PROPagation (RMSPROP)

# %%
import nnfs
from nnfs.datasets import spiral_data
import numpy as np
import matplotlib.pyplot as plt
nnfs.init()

# %%
class Layer_Dense:
    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.01*np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1,n_neurons))
    def forward(self, X):
        self.inputs = X
        self.outputs = np.dot(X, self.weights) + self.biases
    def backward(self, dvalues):
        #dvalues is the gradient of the loss wrt the output of the layer
        self.dweights = np.dot(self.inputs.T, dvalues)
        self.dbiases = np.sum(dvalues, axis = 0, keepdims=True)
        self.dinputs = np.dot(dvalues, self.weights.T)
        
class Activation_ReLU:
    def forward(self, inputs):
        self.inputs = inputs
        self.outputs = np.maximum(0, inputs)
    def backward(self, dvalues):
        #First copy and then check <0 or >0
        self.dinputs = dvalues.copy()
        self.dinputs[self.inputs <= 0] = 0 
        
class Activation_Softmax:
    def forward(self, X):
        not_normalized = np.exp(X - np.max(X, axis = 1, keepdims=True))
        self.outputs = not_normalized/np.sum(not_normalized, axis = 1, keepdims=True)
        
class Loss:
    def calculate(self, y_pred, y_true):
        return np.mean(self.forward(y_pred, y_true))
    
class CategoricalCrossEntropy(Loss): #CCE inherits Loss
    def forward(self, y_pred, y_true):
        #Clip y_pred
        y_pred_clip = np.clip(y_pred, 1e-7, 1 - 1e-7)
        if len(y_true.shape) == 1: #Case 1: Sparse format [0,1,1,2]
            return -np.log(y_pred_clip[range(len(y_pred_clip)), y_true])
        elif len(y_true.shape) == 2: #Case 2: One Hot Encoding of Output
            return -np.log(np.sum(y_pred_clip*y_true, axis = 1)) #Element-wise multiplication
        #Note you are returning negative log likelihood matrix
    def backward(self, dvalues, y_true):
        samples = len(dvalues)
        labels = len(dvalues[0])
    
        #If class labels are sparse, convert to one hot encoded
        if len(y_true.shape) == 1:
            y_true = np.eye(labels)[y_true]
        
        self.dinputs = - y_true/dvalues         #Gradient Calculation
        self.dinputs = self.dinputs/samples     #Normalized with number of samples
        
class Activation_Softmax_CategoricalCrossEntropy:
    def __init__(self):
        self.loss = CategoricalCrossEntropy()
        self.activation = Activation_Softmax()
        
    def forward(self, inputs, y_true):
        self.activation.forward(inputs)
        self.outputs = self.activation.outputs
        return self.loss.calculate(self.outputs, y_true)
    
    def backward(self, dvalues, y_true):
        samples = len(dvalues)
        
        #Convert one-hot encoded y_true to sparse form
        if len(y_true.shape) == 2:
            y_true = np.argmax(y_true, axis = 1)
        
        self.dinputs = dvalues.copy()
        self.dinputs[range(samples), y_true] -= 1
        
        #Normalize this
        self.dinputs = self.dinputs/samples
    
class RMSProp:
    def __init__(self, learning_rate = 1.0, decay = 0, epsilon = 1e-7, rho = 0.99):
        self.learning_rate = learning_rate
        self.current_learning_rate = learning_rate
        self.decay = decay
        self.epsilon = epsilon
        self.rho = rho
        self.iterations = 0
    
    def pre_update_params(self):
        if self.decay:
            self.current_learning_rate = self.learning_rate / (1.0 + self.decay*self.iterations)
    
    def update_params(self, layer):
        if not hasattr(layer, 'weight_cache'):
            layer.weight_cache = np.zeros_like(layer.weights)
            layer.bias_cache = np.zeros_like(layer.biases)
        
        layer.weight_cache = layer.weight_cache*self.rho + (layer.dweights**2)*(1.0 - self.rho)
        layer.bias_cache = layer.bias_cache*self.rho + (layer.dbiases**2)*(1.0 - self.rho)
        
        layer.weights += - (self.current_learning_rate*layer.dweights)/np.sqrt(layer.weight_cache + self.epsilon)
        layer.biases += - (self.current_learning_rate*layer.dbiases)/np.sqrt(layer.bias_cache + self.epsilon)
    
    def post_update_params(self):
        self.iterations += 1

# %%
X, y = spiral_data(samples = 100, classes = 3)

dense1 = Layer_Dense(2, 64)
activation1 = Activation_ReLU()
dense2 = Layer_Dense(64, 3)
loss_activation = Activation_Softmax_CategoricalCrossEntropy()
optimizer = RMSProp(decay = 1e-5, learning_rate=0.02)

for epoch in range(10000):
    dense1.forward(X)
    activation1.forward(dense1.outputs)
    dense2.forward(activation1.outputs)
    loss = loss_activation.forward(dense2.outputs, y)
    y_pred = np.argmax(loss_activation.outputs, axis = 1)
    
    if len(y.shape) == 2:
        y_true = np.argmax(y, axis = 1)
    else:
        y_true = y
    
    accuracy = np.mean(y_true == y_pred)
    
    if (epoch+1)% 100 == 0:
        print(f"Epoch: {epoch+1}\tAccuracy: {accuracy:.3f}\tLoss:{loss:.3f}\tLearning Rate:{optimizer.current_learning_rate:.5f}")
    
    loss_activation.backward(loss_activation.outputs,y_true)
    dense2.backward(loss_activation.dinputs)
    activation1.backward(dense2.dinputs)
    dense1.backward(activation1.dinputs)

    optimizer.pre_update_params()
    optimizer.update_params(dense1)
    optimizer.update_params(dense2)
    optimizer.post_update_params()
# Out:
# Epoch: 100	Accuracy: 0.507	Loss:1.029	Learning Rate:0.01998
# Epoch: 200	Accuracy: 0.450	Loss:0.964	Learning Rate:0.01996
# Epoch: 300	Accuracy: 0.513	Loss:0.930	Learning Rate:0.01994
# Epoch: 400	Accuracy: 0.577	Loss:0.893	Learning Rate:0.01992
# Epoch: 500	Accuracy: 0.577	Loss:0.867	Learning Rate:0.01990
# Epoch: 600	Accuracy: 0.687	Loss:0.794	Learning Rate:0.01988
# Epoch: 700	Accuracy: 0.670	Loss:0.751	Learning Rate:0.01986
# Epoch: 800	Accuracy: 0.650	Loss:0.720	Learning Rate:0.01984
# Epoch: 900	Accuracy: 0.687	Loss:0.683	Learning Rate:0.01982
# Epoch: 1000	Accuracy: 0.727	Loss:0.649	Learning Rate:0.01980
# Epoch: 1100	Accuracy: 0.730	Loss:0.626	Learning Rate:0.01978
# Epoch: 1200	Accuracy: 0.743	Loss:0.603	Learning Rate:0.01976
# Epoch: 1300	Accuracy: 0.750	Loss:0.589	Learning Rate:0.01974
# Epoch: 1400	Accuracy: 0.757	Loss:0.576	Learning Rate:0.01972
# Epoch: 1500	Accuracy: 0.740	Loss:0.562	Learning Rate:0.01970
# Epoch: 1600	Accuracy: 0.737	Loss:0.557	Learning Rate:0.01969
# Epoch: 1700	Accuracy: 0.723	Loss:0.552	Learning Rate:0.01967
# Epoch: 1800	Accuracy: 0.743	Loss:0.530	Learning Rate:0.01965
# Epoch: 1900	Accuracy: 0.757	Loss:0.505	Learning Rate:0.01963
# Epoch: 2000	Accuracy: 0.763	Loss:0.497	Learning Rate:0.01961
# Epoch: 2100	Accuracy: 0.780	Loss:0.488	Learning Rate:0.01959
# Epoch: 2200	Accuracy: 0.763	Loss:0.488	Learning Rate:0.01957
# Epoch: 2300	Accuracy: 0.783	Loss:0.477	Learning Rate:0.01955
# Epoch: 2400	Accuracy: 0.793	Loss:0.472	Learning Rate:0.01953
# Epoch: 2500	Accuracy: 0.793	Loss:0.469	Learning Rate:0.01951
# Epoch: 2600	Accuracy: 0.783	Loss:0.458	Learning Rate:0.01949
# Epoch: 2700	Accuracy: 0.800	Loss:0.462	Learning Rate:0.01947
# Epoch: 2800	Accuracy: 0.787	Loss:0.450	Learning Rate:0.01946
# Epoch: 2900	Accuracy: 0.763	Loss:0.459	Learning Rate:0.01944
# Epoch: 3000	Accuracy: 0.797	Loss:0.439	Learning Rate:0.01942
# Epoch: 3100	Accuracy: 0.810	Loss:0.436	Learning Rate:0.01940
# Epoch: 3200	Accuracy: 0.773	Loss:0.471	Learning Rate:0.01938
# Epoch: 3300	Accuracy: 0.790	Loss:0.466	Learning Rate:0.01936
# Epoch: 3400	Accuracy: 0.797	Loss:0.441	Learning Rate:0.01934
# Epoch: 3500	Accuracy: 0.803	Loss:0.432	Learning Rate:0.01932
# Epoch: 3600	Accuracy: 0.813	Loss:0.427	Learning Rate:0.01931
# Epoch: 3700	Accuracy: 0.813	Loss:0.426	Learning Rate:0.01929
# Epoch: 3800	Accuracy: 0.827	Loss:0.408	Learning Rate:0.01927
# Epoch: 3900	Accuracy: 0.823	Loss:0.404	Learning Rate:0.01925
# Epoch: 4000	Accuracy: 0.773	Loss:0.501	Learning Rate:0.01923
# Epoch: 4100	Accuracy: 0.810	Loss:0.415	Learning Rate:0.01921
# Epoch: 4200	Accuracy: 0.817	Loss:0.405	Learning Rate:0.01919
# Epoch: 4300	Accuracy: 0.810	Loss:0.427	Learning Rate:0.01918
# Epoch: 4400	Accuracy: 0.813	Loss:0.398	Learning Rate:0.01916
# Epoch: 4500	Accuracy: 0.810	Loss:0.415	Learning Rate:0.01914
# Epoch: 4600	Accuracy: 0.813	Loss:0.403	Learning Rate:0.01912
# Epoch: 4700	Accuracy: 0.813	Loss:0.391	Learning Rate:0.01910
# Epoch: 4800	Accuracy: 0.810	Loss:0.404	Learning Rate:0.01908
# Epoch: 4900	Accuracy: 0.813	Loss:0.407	Learning Rate:0.01907
# Epoch: 5000	Accuracy: 0.817	Loss:0.386	Learning Rate:0.01905
# Epoch: 5100	Accuracy: 0.813	Loss:0.405	Learning Rate:0.01903
# Epoch: 5200	Accuracy: 0.840	Loss:0.379	Learning Rate:0.01901
# Epoch: 5300	Accuracy: 0.813	Loss:0.383	Learning Rate:0.01899
# Epoch: 5400	Accuracy: 0.813	Loss:0.401	Learning Rate:0.01898
# Epoch: 5500	Accuracy: 0.840	Loss:0.377	Learning Rate:0.01896
# Epoch: 5600	Accuracy: 0.837	Loss:0.375	Learning Rate:0.01894
# Epoch: 5700	Accuracy: 0.817	Loss:0.389	Learning Rate:0.01892
# Epoch: 5800	Accuracy: 0.803	Loss:0.478	Learning Rate:0.01890
# Epoch: 5900	Accuracy: 0.840	Loss:0.372	Learning Rate:0.01889
# Epoch: 6000	Accuracy: 0.843	Loss:0.357	Learning Rate:0.01887
# Epoch: 6100	Accuracy: 0.843	Loss:0.368	Learning Rate:0.01885
# Epoch: 6200	Accuracy: 0.840	Loss:0.363	Learning Rate:0.01883
# Epoch: 6300	Accuracy: 0.840	Loss:0.389	Learning Rate:0.01882
# Epoch: 6400	Accuracy: 0.837	Loss:0.375	Learning Rate:0.01880
# Epoch: 6500	Accuracy: 0.823	Loss:0.390	Learning Rate:0.01878
# Epoch: 6600	Accuracy: 0.850	Loss:0.360	Learning Rate:0.01876
# Epoch: 6700	Accuracy: 0.850	Loss:0.344	Learning Rate:0.01874
# Epoch: 6800	Accuracy: 0.803	Loss:0.422	Learning Rate:0.01873
# Epoch: 6900	Accuracy: 0.850	Loss:0.344	Learning Rate:0.01871
# Epoch: 7000	Accuracy: 0.850	Loss:0.353	Learning Rate:0.01869
# Epoch: 7100	Accuracy: 0.843	Loss:0.348	Learning Rate:0.01867
# Epoch: 7200	Accuracy: 0.847	Loss:0.337	Learning Rate:0.01866
# Epoch: 7300	Accuracy: 0.850	Loss:0.337	Learning Rate:0.01864
# Epoch: 7400	Accuracy: 0.843	Loss:0.341	Learning Rate:0.01862
# Epoch: 7500	Accuracy: 0.813	Loss:0.377	Learning Rate:0.01860
# Epoch: 7600	Accuracy: 0.813	Loss:0.456	Learning Rate:0.01859
# Epoch: 7700	Accuracy: 0.827	Loss:0.364	Learning Rate:0.01857
# Epoch: 7800	Accuracy: 0.843	Loss:0.351	Learning Rate:0.01855
# Epoch: 7900	Accuracy: 0.827	Loss:0.350	Learning Rate:0.01854
# Epoch: 8000	Accuracy: 0.823	Loss:0.348	Learning Rate:0.01852
# Epoch: 8100	Accuracy: 0.850	Loss:0.346	Learning Rate:0.01850
# Epoch: 8200	Accuracy: 0.830	Loss:0.344	Learning Rate:0.01848
# Epoch: 8300	Accuracy: 0.830	Loss:0.343	Learning Rate:0.01847
# Epoch: 8400	Accuracy: 0.853	Loss:0.344	Learning Rate:0.01845
# Epoch: 8500	Accuracy: 0.823	Loss:0.355	Learning Rate:0.01843
# Epoch: 8600	Accuracy: 0.870	Loss:0.322	Learning Rate:0.01842
# Epoch: 8700	Accuracy: 0.807	Loss:0.403	Learning Rate:0.01840
# Epoch: 8800	Accuracy: 0.830	Loss:0.338	Learning Rate:0.01838
# Epoch: 8900	Accuracy: 0.830	Loss:0.339	Learning Rate:0.01837
# Epoch: 9000	Accuracy: 0.850	Loss:0.341	Learning Rate:0.01835
# Epoch: 9100	Accuracy: 0.847	Loss:0.344	Learning Rate:0.01833
# Epoch: 9200	Accuracy: 0.820	Loss:0.341	Learning Rate:0.01832
# Epoch: 9300	Accuracy: 0.827	Loss:0.337	Learning Rate:0.01830
# Epoch: 9400	Accuracy: 0.847	Loss:0.345	Learning Rate:0.01828
# Epoch: 9500	Accuracy: 0.840	Loss:0.334	Learning Rate:0.01827
# Epoch: 9600	Accuracy: 0.843	Loss:0.320	Learning Rate:0.01825
# Epoch: 9700	Accuracy: 0.860	Loss:0.321	Learning Rate:0.01823
# Epoch: 9800	Accuracy: 0.840	Loss:0.331	Learning Rate:0.01822
# Epoch: 9900	Accuracy: 0.837	Loss:0.331	Learning Rate:0.01820
# Epoch: 10000	Accuracy: 0.857	Loss:0.337	Learning Rate:0.01818
