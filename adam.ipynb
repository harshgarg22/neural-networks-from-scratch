# %% [markdown]
# # ADAptive Moment Estimation (ADAM)

# %%
import nnfs
from nnfs.datasets import spiral_data
import numpy as np
import matplotlib.pyplot as plt
nnfs.init()

# %%
class Layer_Dense:
    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.01*np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1,n_neurons))
    def forward(self, X):
        self.inputs = X
        self.outputs = np.dot(X, self.weights) + self.biases
    def backward(self, dvalues):
        #dvalues is the gradient of the loss wrt the output of the layer
        self.dweights = np.dot(self.inputs.T, dvalues)
        self.dbiases = np.sum(dvalues, axis = 0, keepdims=True)
        self.dinputs = np.dot(dvalues, self.weights.T)
        
class Activation_ReLU:
    def forward(self, inputs):
        self.inputs = inputs
        self.outputs = np.maximum(0, inputs)
    def backward(self, dvalues):
        #First copy and then check <0 or >0
        self.dinputs = dvalues.copy()
        self.dinputs[self.inputs <= 0] = 0 
        
class Activation_Softmax:
    def forward(self, X):
        not_normalized = np.exp(X - np.max(X, axis = 1, keepdims=True))
        self.outputs = not_normalized/np.sum(not_normalized, axis = 1, keepdims=True)
        
class Loss:
    def calculate(self, y_pred, y_true):
        return np.mean(self.forward(y_pred, y_true))
    
class CategoricalCrossEntropy(Loss): #CCE inherits Loss
    def forward(self, y_pred, y_true):
        #Clip y_pred
        y_pred_clip = np.clip(y_pred, 1e-7, 1 - 1e-7)
        if len(y_true.shape) == 1: #Case 1: Sparse format [0,1,1,2]
            return -np.log(y_pred_clip[range(len(y_pred_clip)), y_true])
        elif len(y_true.shape) == 2: #Case 2: One Hot Encoding of Output
            return -np.log(np.sum(y_pred_clip*y_true, axis = 1)) #Element-wise multiplication
        #Note you are returning negative log likelihood matrix
    def backward(self, dvalues, y_true):
        samples = len(dvalues)
        labels = len(dvalues[0])
    
        #If class labels are sparse, convert to one hot encoded
        if len(y_true.shape) == 1:
            y_true = np.eye(labels)[y_true]
        
        self.dinputs = - y_true/dvalues         #Gradient Calculation
        self.dinputs = self.dinputs/samples     #Normalized with number of samples
        
class Activation_Softmax_CategoricalCrossEntropy:
    def __init__(self):
        self.loss = CategoricalCrossEntropy()
        self.activation = Activation_Softmax()
        
    def forward(self, inputs, y_true):
        self.activation.forward(inputs)
        self.outputs = self.activation.outputs
        return self.loss.calculate(self.outputs, y_true)
    
    def backward(self, dvalues, y_true):
        samples = len(dvalues)
        
        #Convert one-hot encoded y_true to sparse form
        if len(y_true.shape) == 2:
            y_true = np.argmax(y_true, axis = 1)
        
        self.dinputs = dvalues.copy()
        self.dinputs[range(samples), y_true] -= 1
        
        #Normalize this
        self.dinputs = self.dinputs/samples
    
class ADAM:
    def __init__(self, beta1 = 0.9, beta2 = 0.999, epsilon = 1e-7, learning_rate = 0.001, decay = 0):
        self.learning_rate = learning_rate
        self.current_learning_rate = learning_rate
        self.decay = decay
        self.iterations = 0
        self.beta1 = beta1
        self.beta2 = beta2
        self.epsilon = epsilon
    
    def pre_update_params(self):
        if self.decay:
            self.current_learning_rate = (self.learning_rate)/(1. + self.decay*self.iterations)
    
    def update_params(self, layer):
        if not hasattr(layer, 'weight_cache'):
            layer.weight_cache = np.zeros_like(layer.weights)
            layer.bias_cache = np.zeros_like(layer.biases)
            layer.weight_momentums = np.zeros_like(layer.weights)
            layer.bias_momentums = np.zeros_like(layer.biases)
            
        #Update the cache bby adding the current gradient squared
        layer.weight_cache = layer.weight_cache*self.beta2 + (layer.dweights**2)*(1 - self.beta2)
        layer.bias_cache = layer.bias_cache*self.beta2 + (layer.dbiases**2)*(1 - self.beta2)
        
        #Correct both by the division factor
        weight_cache_corrected = (layer.weight_cache) / (1 - (self.beta2**(self.iterations + 1)))
        bias_cache_corrected = (layer.bias_cache) / (1 - (self.beta2**(self.iterations + 1)))
        
        #Update the momentums by adding current gradient
        layer.weight_momentums = layer.weight_momentums*self.beta1 + (layer.dweights)*(1 - self.beta1)
        layer.bias_momentums = layer.bias_momentums*self.beta1 + (layer.dbiases)*(1 - self.beta1)
        
        #Correction
        weight_momentums_corrected = (layer.weight_momentums) / (1 - (self.beta1**(self.iterations + 1)))
        bias_momentums_corrected = (layer.bias_momentums) / (1 - (self.beta1**(self.iterations + 1)))
        
        #Final weight and bias update
        layer.weights += -(self.current_learning_rate*weight_momentums_corrected) / np.sqrt(weight_cache_corrected + self.epsilon)
        layer.biases += -(self.current_learning_rate*bias_momentums_corrected) / np.sqrt(bias_cache_corrected + self.epsilon)
    
    def post_update_params(self):
        self.iterations += 1

# %%
X, y = spiral_data(samples = 100, classes = 3)

dense1 = Layer_Dense(2, 64)
activation1 = Activation_ReLU()
dense2 = Layer_Dense(64, 3)
loss_activation = Activation_Softmax_CategoricalCrossEntropy()
optimizer = ADAM(decay = 1e-5, learning_rate=0.02)

for epoch in range(10000):
    dense1.forward(X)
    activation1.forward(dense1.outputs)
    dense2.forward(activation1.outputs)
    loss = loss_activation.forward(dense2.outputs, y)
    y_pred = np.argmax(loss_activation.outputs, axis = 1)
    
    if len(y.shape) == 2:
        y_true = np.argmax(y, axis = 1)
    else:
        y_true = y
    
    accuracy = np.mean(y_true == y_pred)
    
    if (epoch+1)% 100 == 0:
        print(f"Epoch: {epoch+1}\tAccuracy: {accuracy:.3f}\tLoss:{loss:.3f}\tLearning Rate:{optimizer.current_learning_rate:.5f}")
    
    loss_activation.backward(loss_activation.outputs,y_true)
    dense2.backward(loss_activation.dinputs)
    activation1.backward(dense2.dinputs)
    dense1.backward(activation1.dinputs)

    optimizer.pre_update_params()
    optimizer.update_params(dense1)
    optimizer.update_params(dense2)
    optimizer.post_update_params()
# Out:
# Epoch: 100	Accuracy: 0.567	Loss:0.972	Learning Rate:0.01998
# Epoch: 200	Accuracy: 0.693	Loss:0.801	Learning Rate:0.01996
# Epoch: 300	Accuracy: 0.683	Loss:0.727	Learning Rate:0.01994
# Epoch: 400	Accuracy: 0.727	Loss:0.679	Learning Rate:0.01992
# Epoch: 500	Accuracy: 0.750	Loss:0.635	Learning Rate:0.01990
# Epoch: 600	Accuracy: 0.770	Loss:0.592	Learning Rate:0.01988
# Epoch: 700	Accuracy: 0.790	Loss:0.566	Learning Rate:0.01986
# Epoch: 800	Accuracy: 0.807	Loss:0.543	Learning Rate:0.01984
# Epoch: 900	Accuracy: 0.800	Loss:0.524	Learning Rate:0.01982
# Epoch: 1000	Accuracy: 0.823	Loss:0.507	Learning Rate:0.01980
# Epoch: 1100	Accuracy: 0.813	Loss:0.494	Learning Rate:0.01978
# Epoch: 1200	Accuracy: 0.820	Loss:0.483	Learning Rate:0.01976
# Epoch: 1300	Accuracy: 0.830	Loss:0.472	Learning Rate:0.01974
# Epoch: 1400	Accuracy: 0.817	Loss:0.469	Learning Rate:0.01972
# Epoch: 1500	Accuracy: 0.840	Loss:0.455	Learning Rate:0.01970
# Epoch: 1600	Accuracy: 0.853	Loss:0.449	Learning Rate:0.01969
# Epoch: 1700	Accuracy: 0.863	Loss:0.442	Learning Rate:0.01967
# Epoch: 1800	Accuracy: 0.853	Loss:0.438	Learning Rate:0.01965
# Epoch: 1900	Accuracy: 0.850	Loss:0.432	Learning Rate:0.01963
# Epoch: 2000	Accuracy: 0.863	Loss:0.424	Learning Rate:0.01961
# Epoch: 2100	Accuracy: 0.847	Loss:0.420	Learning Rate:0.01959
# Epoch: 2200	Accuracy: 0.867	Loss:0.408	Learning Rate:0.01957
# Epoch: 2300	Accuracy: 0.850	Loss:0.395	Learning Rate:0.01955
# Epoch: 2400	Accuracy: 0.857	Loss:0.381	Learning Rate:0.01953
# Epoch: 2500	Accuracy: 0.860	Loss:0.373	Learning Rate:0.01951
# Epoch: 2600	Accuracy: 0.870	Loss:0.367	Learning Rate:0.01949
# Epoch: 2700	Accuracy: 0.870	Loss:0.365	Learning Rate:0.01947
# Epoch: 2800	Accuracy: 0.873	Loss:0.356	Learning Rate:0.01946
# Epoch: 2900	Accuracy: 0.873	Loss:0.352	Learning Rate:0.01944
# Epoch: 3000	Accuracy: 0.880	Loss:0.346	Learning Rate:0.01942
# Epoch: 3100	Accuracy: 0.877	Loss:0.345	Learning Rate:0.01940
# Epoch: 3200	Accuracy: 0.880	Loss:0.339	Learning Rate:0.01938
# Epoch: 3300	Accuracy: 0.863	Loss:0.346	Learning Rate:0.01936
# Epoch: 3400	Accuracy: 0.883	Loss:0.334	Learning Rate:0.01934
# Epoch: 3500	Accuracy: 0.873	Loss:0.329	Learning Rate:0.01932
# Epoch: 3600	Accuracy: 0.877	Loss:0.325	Learning Rate:0.01931
# Epoch: 3700	Accuracy: 0.867	Loss:0.327	Learning Rate:0.01929
# Epoch: 3800	Accuracy: 0.877	Loss:0.313	Learning Rate:0.01927
# Epoch: 3900	Accuracy: 0.887	Loss:0.307	Learning Rate:0.01925
# Epoch: 4000	Accuracy: 0.880	Loss:0.306	Learning Rate:0.01923
# Epoch: 4100	Accuracy: 0.890	Loss:0.298	Learning Rate:0.01921
# Epoch: 4200	Accuracy: 0.890	Loss:0.303	Learning Rate:0.01919
# Epoch: 4300	Accuracy: 0.890	Loss:0.293	Learning Rate:0.01918
# Epoch: 4400	Accuracy: 0.887	Loss:0.289	Learning Rate:0.01916
# Epoch: 4500	Accuracy: 0.890	Loss:0.290	Learning Rate:0.01914
# Epoch: 4600	Accuracy: 0.897	Loss:0.288	Learning Rate:0.01912
# Epoch: 4700	Accuracy: 0.893	Loss:0.279	Learning Rate:0.01910
# Epoch: 4800	Accuracy: 0.900	Loss:0.278	Learning Rate:0.01908
# Epoch: 4900	Accuracy: 0.900	Loss:0.272	Learning Rate:0.01907
# Epoch: 5000	Accuracy: 0.900	Loss:0.272	Learning Rate:0.01905
# Epoch: 5100	Accuracy: 0.893	Loss:0.270	Learning Rate:0.01903
# Epoch: 5200	Accuracy: 0.903	Loss:0.263	Learning Rate:0.01901
# Epoch: 5300	Accuracy: 0.903	Loss:0.264	Learning Rate:0.01899
# Epoch: 5400	Accuracy: 0.897	Loss:0.259	Learning Rate:0.01898
# Epoch: 5500	Accuracy: 0.907	Loss:0.257	Learning Rate:0.01896
# Epoch: 5600	Accuracy: 0.907	Loss:0.254	Learning Rate:0.01894
# Epoch: 5700	Accuracy: 0.907	Loss:0.254	Learning Rate:0.01892
# Epoch: 5800	Accuracy: 0.907	Loss:0.249	Learning Rate:0.01890
# Epoch: 5900	Accuracy: 0.910	Loss:0.247	Learning Rate:0.01889
# Epoch: 6000	Accuracy: 0.903	Loss:0.245	Learning Rate:0.01887
# Epoch: 6100	Accuracy: 0.907	Loss:0.243	Learning Rate:0.01885
# Epoch: 6200	Accuracy: 0.910	Loss:0.242	Learning Rate:0.01883
# Epoch: 6300	Accuracy: 0.903	Loss:0.241	Learning Rate:0.01882
# Epoch: 6400	Accuracy: 0.907	Loss:0.239	Learning Rate:0.01880
# Epoch: 6500	Accuracy: 0.907	Loss:0.238	Learning Rate:0.01878
# Epoch: 6600	Accuracy: 0.897	Loss:0.253	Learning Rate:0.01876
# Epoch: 6700	Accuracy: 0.910	Loss:0.242	Learning Rate:0.01874
# Epoch: 6800	Accuracy: 0.907	Loss:0.232	Learning Rate:0.01873
# Epoch: 6900	Accuracy: 0.907	Loss:0.231	Learning Rate:0.01871
# Epoch: 7000	Accuracy: 0.907	Loss:0.231	Learning Rate:0.01869
# Epoch: 7100	Accuracy: 0.920	Loss:0.231	Learning Rate:0.01867
# Epoch: 7200	Accuracy: 0.917	Loss:0.233	Learning Rate:0.01866
# Epoch: 7300	Accuracy: 0.917	Loss:0.226	Learning Rate:0.01864
# Epoch: 7400	Accuracy: 0.910	Loss:0.226	Learning Rate:0.01862
# Epoch: 7500	Accuracy: 0.920	Loss:0.224	Learning Rate:0.01860
# Epoch: 7600	Accuracy: 0.910	Loss:0.223	Learning Rate:0.01859
# Epoch: 7700	Accuracy: 0.910	Loss:0.220	Learning Rate:0.01857
# Epoch: 7800	Accuracy: 0.913	Loss:0.222	Learning Rate:0.01855
# Epoch: 7900	Accuracy: 0.913	Loss:0.221	Learning Rate:0.01854
# Epoch: 8000	Accuracy: 0.920	Loss:0.222	Learning Rate:0.01852
# Epoch: 8100	Accuracy: 0.913	Loss:0.216	Learning Rate:0.01850
# Epoch: 8200	Accuracy: 0.917	Loss:0.218	Learning Rate:0.01848
# Epoch: 8300	Accuracy: 0.910	Loss:0.212	Learning Rate:0.01847
# Epoch: 8400	Accuracy: 0.930	Loss:0.208	Learning Rate:0.01845
# Epoch: 8500	Accuracy: 0.930	Loss:0.206	Learning Rate:0.01843
# Epoch: 8600	Accuracy: 0.927	Loss:0.207	Learning Rate:0.01842
# Epoch: 8700	Accuracy: 0.933	Loss:0.204	Learning Rate:0.01840
# Epoch: 8800	Accuracy: 0.930	Loss:0.203	Learning Rate:0.01838
# Epoch: 8900	Accuracy: 0.933	Loss:0.200	Learning Rate:0.01837
# Epoch: 9000	Accuracy: 0.930	Loss:0.197	Learning Rate:0.01835
# Epoch: 9100	Accuracy: 0.937	Loss:0.197	Learning Rate:0.01833
# Epoch: 9200	Accuracy: 0.930	Loss:0.195	Learning Rate:0.01832
# Epoch: 9300	Accuracy: 0.927	Loss:0.202	Learning Rate:0.01830
# Epoch: 9400	Accuracy: 0.930	Loss:0.193	Learning Rate:0.01828
# Epoch: 9500	Accuracy: 0.937	Loss:0.197	Learning Rate:0.01827
# Epoch: 9600	Accuracy: 0.930	Loss:0.191	Learning Rate:0.01825
# Epoch: 9700	Accuracy: 0.930	Loss:0.191	Learning Rate:0.01823
# Epoch: 9800	Accuracy: 0.933	Loss:0.189	Learning Rate:0.01822
# Epoch: 9900	Accuracy: 0.933	Loss:0.191	Learning Rate:0.01820
# Epoch: 10000	Accuracy: 0.930	Loss:0.191	Learning Rate:0.01818
