# %% [markdown]
# ## Momentum with Gradient Descent (Implemented with Learning Rate Decay)

# %%
import nnfs
from nnfs.datasets import spiral_data
import numpy as np
import matplotlib.pyplot as plt
nnfs.init()

# %% [markdown]
# ### Gradient Descent is updated to include Momentum + Learning Rate Decay

# %%
class Layer_Dense:
    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.01*np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1,n_neurons))
    def forward(self, X):
        self.inputs = X
        self.outputs = np.dot(X, self.weights) + self.biases
    def backward(self, dvalues):
        #dvalues is the gradient of the loss wrt the output of the layer
        self.dweights = np.dot(self.inputs.T, dvalues)
        self.dbiases = np.sum(dvalues, axis = 0, keepdims=True)
        self.dinputs = np.dot(dvalues, self.weights.T)
        
class Activation_ReLU:
    def forward(self, inputs):
        self.inputs = inputs
        self.outputs = np.maximum(0, inputs)
    def backward(self, dvalues):
        #First copy and then check <0 or >0
        self.dinputs = dvalues.copy()
        self.dinputs[self.inputs <= 0] = 0 
        
class Activation_Softmax:
    def forward(self, X):
        not_normalized = np.exp(X - np.max(X, axis = 1, keepdims=True))
        self.outputs = not_normalized/np.sum(not_normalized, axis = 1, keepdims=True)
        
class Loss:
    def calculate(self, y_pred, y_true):
        return np.mean(self.forward(y_pred, y_true))
    
class CategoricalCrossEntropy(Loss): #CCE inherits Loss
    def forward(self, y_pred, y_true):
        #Clip y_pred
        y_pred_clip = np.clip(y_pred, 1e-7, 1 - 1e-7)
        if len(y_true.shape) == 1: #Case 1: Sparse format [0,1,1,2]
            return -np.log(y_pred_clip[range(len(y_pred_clip)), y_true])
        elif len(y_true.shape) == 2: #Case 2: One Hot Encoding of Output
            return -np.log(np.sum(y_pred_clip*y_true, axis = 1)) #Element-wise multiplication
        #Note you are returning negative log likelihood matrix
    def backward(self, dvalues, y_true):
        samples = len(dvalues)
        labels = len(dvalues[0])
    
        #If class labels are sparse, convert to one hot encoded
        if len(y_true.shape) == 1:
            y_true = np.eye(labels)[y_true]
        
        self.dinputs = - y_true/dvalues         #Gradient Calculation
        self.dinputs = self.dinputs/samples     #Normalized with number of samples
        
class Activation_Softmax_CategoricalCrossEntropy:
    def __init__(self):
        self.loss = CategoricalCrossEntropy()
        self.activation = Activation_Softmax()
        
    def forward(self, inputs, y_true):
        self.activation.forward(inputs)
        self.outputs = self.activation.outputs
        return self.loss.calculate(self.outputs, y_true)
    
    def backward(self, dvalues, y_true):
        samples = len(dvalues)
        
        #Convert one-hot encoded y_true to sparse form
        if len(y_true.shape) == 2:
            y_true = np.argmax(y_true, axis = 1)
        
        self.dinputs = dvalues.copy()
        self.dinputs[range(samples), y_true] -= 1
        
        #Normalize this
        self.dinputs = self.dinputs/samples
    
class GradientDescent:
    def __init__(self, learning_rate = 1.0, decay = 0., momentum = 0.):
        self.learning_rate = learning_rate
        self.current_learning_rate = learning_rate
        self.decay = decay
        self.iterations = 0
        self.momentum = momentum
        
    def pre_update_params(self):
        if self.decay:
            self.current_learning_rate = (self.learning_rate)/(1.0 + (self.decay)*(self.iterations))
    
    def update_params(self, layer):
        if self.momentum:
            if not hasattr(layer, 'weight_momentums'):
                #Creating the attributes in the layer class that will store our previous updates
                layer.weight_momentums = np.zeros_like(layer.weights)
                layer.bias_momentums = np.zeros_like(layer.biases)
            
            #Creating weight and bias update and storing as previous values of updates
            weight_updates = (self.momentum * layer.weight_momentums) - (self.current_learning_rate * layer.dweights)
            layer.weight_momentums = weight_updates
            
            bias_updates = (self.momentum * layer.bias_momentums) - (self.current_learning_rate * layer.dbiases)
            layer.bias_momentums = bias_updates
        else:
            #Vanilla Gradient Descent
            weight_updates = - (self.current_learning_rate * layer.dweights)
            bias_updates = - (self.current_learning_rate * layer.dbiases)
        
        #Finally update the weights and biases
        layer.weights += weight_updates
        layer.biases += bias_updates
    
    def post_update_params(self):
        self.iterations += 1

# %% [markdown]
# ### Coding forward and backward pass with learning rate decay, momentum and gradient descent

# %%
X, y = spiral_data(samples = 100, classes = 3)

dense1 = Layer_Dense(2, 64)
activation1 = Activation_ReLU()
dense2 = Layer_Dense(64, 3)
loss_activation = Activation_Softmax_CategoricalCrossEntropy()
optimizer = GradientDescent(decay=1e-3, momentum=0.9)

for epoch in range(10000):
    dense1.forward(X)
    activation1.forward(dense1.outputs)
    dense2.forward(activation1.outputs)
    loss = loss_activation.forward(dense2.outputs, y)
    y_pred = np.argmax(loss_activation.outputs, axis = 1)
    
    if len(y.shape) == 2:
        y_true = np.argmax(y, axis = 1)
    else:
        y_true = y
    
    accuracy = np.mean(y_true == y_pred)
    
    if (epoch+1)% 100 == 0:
        print(f"Epoch: {epoch+1}\tAccuracy: {accuracy:.3f}\tLoss:{loss:.3f}\tLearning Rate:{optimizer.current_learning_rate:.5f}")
    
    loss_activation.backward(loss_activation.outputs,y_true)
    dense2.backward(loss_activation.dinputs)
    activation1.backward(dense2.dinputs)
    dense1.backward(activation1.dinputs)

    optimizer.pre_update_params()
    optimizer.update_params(dense1)
    optimizer.update_params(dense2)
    optimizer.post_update_params()
# Out:
# Epoch: 100	Accuracy: 0.457	Loss:1.011	Learning Rate:0.91075
# Epoch: 200	Accuracy: 0.383	Loss:0.964	Learning Rate:0.83472
# Epoch: 300	Accuracy: 0.683	Loss:0.741	Learning Rate:0.77042
# Epoch: 400	Accuracy: 0.767	Loss:0.531	Learning Rate:0.71531
# Epoch: 500	Accuracy: 0.847	Loss:0.427	Learning Rate:0.66756
# Epoch: 600	Accuracy: 0.883	Loss:0.365	Learning Rate:0.62578
# Epoch: 700	Accuracy: 0.900	Loss:0.304	Learning Rate:0.58893
# Epoch: 800	Accuracy: 0.903	Loss:0.280	Learning Rate:0.55617
# Epoch: 900	Accuracy: 0.900	Loss:0.267	Learning Rate:0.52687
# Epoch: 1000	Accuracy: 0.893	Loss:0.277	Learning Rate:0.50050
# Epoch: 1100	Accuracy: 0.903	Loss:0.258	Learning Rate:0.47664
# Epoch: 1200	Accuracy: 0.910	Loss:0.226	Learning Rate:0.45496
# Epoch: 1300	Accuracy: 0.857	Loss:0.347	Learning Rate:0.43516
# Epoch: 1400	Accuracy: 0.920	Loss:0.213	Learning Rate:0.41701
# Epoch: 1500	Accuracy: 0.917	Loss:0.206	Learning Rate:0.40032
# Epoch: 1600	Accuracy: 0.900	Loss:0.228	Learning Rate:0.38491
# Epoch: 1700	Accuracy: 0.917	Loss:0.198	Learning Rate:0.37064
# Epoch: 1800	Accuracy: 0.913	Loss:0.194	Learning Rate:0.35740
# Epoch: 1900	Accuracy: 0.923	Loss:0.194	Learning Rate:0.34507
# Epoch: 2000	Accuracy: 0.917	Loss:0.187	Learning Rate:0.33356
# Epoch: 2100	Accuracy: 0.927	Loss:0.189	Learning Rate:0.32279
# Epoch: 2200	Accuracy: 0.913	Loss:0.182	Learning Rate:0.31270
# Epoch: 2300	Accuracy: 0.920	Loss:0.182	Learning Rate:0.30321
# Epoch: 2400	Accuracy: 0.920	Loss:0.179	Learning Rate:0.29429
# Epoch: 2500	Accuracy: 0.920	Loss:0.179	Learning Rate:0.28588
# Epoch: 2600	Accuracy: 0.913	Loss:0.178	Learning Rate:0.27793
# Epoch: 2700	Accuracy: 0.927	Loss:0.177	Learning Rate:0.27042
# Epoch: 2800	Accuracy: 0.920	Loss:0.170	Learning Rate:0.26330
# Epoch: 2900	Accuracy: 0.930	Loss:0.169	Learning Rate:0.25654
# Epoch: 3000	Accuracy: 0.923	Loss:0.167	Learning Rate:0.25013
# Epoch: 3100	Accuracy: 0.923	Loss:0.166	Learning Rate:0.24402
# Epoch: 3200	Accuracy: 0.927	Loss:0.164	Learning Rate:0.23821
# Epoch: 3300	Accuracy: 0.933	Loss:0.162	Learning Rate:0.23267
# Epoch: 3400	Accuracy: 0.930	Loss:0.161	Learning Rate:0.22738
# Epoch: 3500	Accuracy: 0.927	Loss:0.160	Learning Rate:0.22232
# Epoch: 3600	Accuracy: 0.927	Loss:0.158	Learning Rate:0.21749
# Epoch: 3700	Accuracy: 0.930	Loss:0.158	Learning Rate:0.21286
# Epoch: 3800	Accuracy: 0.927	Loss:0.156	Learning Rate:0.20842
# Epoch: 3900	Accuracy: 0.933	Loss:0.155	Learning Rate:0.20416
# Epoch: 4000	Accuracy: 0.937	Loss:0.153	Learning Rate:0.20008
# Epoch: 4100	Accuracy: 0.933	Loss:0.153	Learning Rate:0.19616
# Epoch: 4200	Accuracy: 0.937	Loss:0.151	Learning Rate:0.19238
# Epoch: 4300	Accuracy: 0.937	Loss:0.149	Learning Rate:0.18875
# Epoch: 4400	Accuracy: 0.947	Loss:0.148	Learning Rate:0.18525
# Epoch: 4500	Accuracy: 0.943	Loss:0.147	Learning Rate:0.18188
# Epoch: 4600	Accuracy: 0.940	Loss:0.146	Learning Rate:0.17864
# Epoch: 4700	Accuracy: 0.943	Loss:0.145	Learning Rate:0.17550
# Epoch: 4800	Accuracy: 0.940	Loss:0.144	Learning Rate:0.17247
# Epoch: 4900	Accuracy: 0.940	Loss:0.143	Learning Rate:0.16955
# Epoch: 5000	Accuracy: 0.940	Loss:0.142	Learning Rate:0.16672
# Epoch: 5100	Accuracy: 0.943	Loss:0.142	Learning Rate:0.16399
# Epoch: 5200	Accuracy: 0.943	Loss:0.141	Learning Rate:0.16134
# Epoch: 5300	Accuracy: 0.943	Loss:0.140	Learning Rate:0.15878
# Epoch: 5400	Accuracy: 0.943	Loss:0.139	Learning Rate:0.15630
# Epoch: 5500	Accuracy: 0.943	Loss:0.139	Learning Rate:0.15389
# Epoch: 5600	Accuracy: 0.943	Loss:0.138	Learning Rate:0.15156
# Epoch: 5700	Accuracy: 0.943	Loss:0.137	Learning Rate:0.14930
# Epoch: 5800	Accuracy: 0.943	Loss:0.136	Learning Rate:0.14710
# Epoch: 5900	Accuracy: 0.943	Loss:0.136	Learning Rate:0.14497
# Epoch: 6000	Accuracy: 0.950	Loss:0.135	Learning Rate:0.14290
# Epoch: 6100	Accuracy: 0.953	Loss:0.134	Learning Rate:0.14088
# Epoch: 6200	Accuracy: 0.950	Loss:0.134	Learning Rate:0.13893
# Epoch: 6300	Accuracy: 0.950	Loss:0.133	Learning Rate:0.13702
# Epoch: 6400	Accuracy: 0.953	Loss:0.133	Learning Rate:0.13517
# Epoch: 6500	Accuracy: 0.950	Loss:0.132	Learning Rate:0.13337
# Epoch: 6600	Accuracy: 0.950	Loss:0.132	Learning Rate:0.13161
# Epoch: 6700	Accuracy: 0.950	Loss:0.131	Learning Rate:0.12990
# Epoch: 6800	Accuracy: 0.953	Loss:0.131	Learning Rate:0.12824
# Epoch: 6900	Accuracy: 0.953	Loss:0.130	Learning Rate:0.12661
# Epoch: 7000	Accuracy: 0.953	Loss:0.130	Learning Rate:0.12503
# Epoch: 7100	Accuracy: 0.953	Loss:0.129	Learning Rate:0.12349
# Epoch: 7200	Accuracy: 0.950	Loss:0.129	Learning Rate:0.12198
# Epoch: 7300	Accuracy: 0.947	Loss:0.128	Learning Rate:0.12051
# Epoch: 7400	Accuracy: 0.953	Loss:0.128	Learning Rate:0.11908
# Epoch: 7500	Accuracy: 0.947	Loss:0.128	Learning Rate:0.11767
# Epoch: 7600	Accuracy: 0.953	Loss:0.127	Learning Rate:0.11631
# Epoch: 7700	Accuracy: 0.953	Loss:0.127	Learning Rate:0.11497
# Epoch: 7800	Accuracy: 0.953	Loss:0.126	Learning Rate:0.11366
# Epoch: 7900	Accuracy: 0.953	Loss:0.126	Learning Rate:0.11238
# Epoch: 8000	Accuracy: 0.953	Loss:0.126	Learning Rate:0.11114
# Epoch: 8100	Accuracy: 0.953	Loss:0.125	Learning Rate:0.10991
# Epoch: 8200	Accuracy: 0.950	Loss:0.125	Learning Rate:0.10872
# Epoch: 8300	Accuracy: 0.957	Loss:0.125	Learning Rate:0.10755
# Epoch: 8400	Accuracy: 0.957	Loss:0.124	Learning Rate:0.10641
# Epoch: 8500	Accuracy: 0.953	Loss:0.124	Learning Rate:0.10529
# Epoch: 8600	Accuracy: 0.957	Loss:0.124	Learning Rate:0.10419
# Epoch: 8700	Accuracy: 0.960	Loss:0.123	Learning Rate:0.10311
# Epoch: 8800	Accuracy: 0.960	Loss:0.123	Learning Rate:0.10206
# Epoch: 8900	Accuracy: 0.957	Loss:0.123	Learning Rate:0.10103
# Epoch: 9000	Accuracy: 0.960	Loss:0.122	Learning Rate:0.10002
# Epoch: 9100	Accuracy: 0.960	Loss:0.122	Learning Rate:0.09903
# Epoch: 9200	Accuracy: 0.960	Loss:0.122	Learning Rate:0.09806
# Epoch: 9300	Accuracy: 0.960	Loss:0.122	Learning Rate:0.09711
# Epoch: 9400	Accuracy: 0.960	Loss:0.121	Learning Rate:0.09617
# Epoch: 9500	Accuracy: 0.957	Loss:0.121	Learning Rate:0.09526
# Epoch: 9600	Accuracy: 0.960	Loss:0.121	Learning Rate:0.09436
# Epoch: 9700	Accuracy: 0.957	Loss:0.120	Learning Rate:0.09348
# Epoch: 9800	Accuracy: 0.957	Loss:0.120	Learning Rate:0.09261
# Epoch: 9900	Accuracy: 0.960	Loss:0.120	Learning Rate:0.09176
# Epoch: 10000	Accuracy: 0.960	Loss:0.120	Learning Rate:0.09093
