# %% [markdown]
# ## Decaying Learning Rate and Gradient Descent

# %%
import nnfs
from nnfs.datasets import spiral_data
import numpy as np
import matplotlib.pyplot as plt
nnfs.init()

# %% [markdown]
# ### Vanilla Gradient Descent is updated to include Learning Rate Decay

# %%
class Layer_Dense:
    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.01*np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1,n_neurons))
    def forward(self, X):
        self.inputs = X
        self.outputs = np.dot(X, self.weights) + self.biases
    def backward(self, dvalues):
        #dvalues is the gradient of the loss wrt the output of the layer
        self.dweights = np.dot(self.inputs.T, dvalues)
        self.dbiases = np.sum(dvalues, axis = 0, keepdims=True)
        self.dinputs = np.dot(dvalues, self.weights.T)
        
class Activation_ReLU:
    def forward(self, inputs):
        self.inputs = inputs
        self.outputs = np.maximum(0, inputs)
    def backward(self, dvalues):
        #First copy and then check <0 or >0
        self.dinputs = dvalues.copy()
        self.dinputs[self.inputs <= 0] = 0 
        
class Activation_Softmax:
    def forward(self, X):
        not_normalized = np.exp(X - np.max(X, axis = 1, keepdims=True))
        self.outputs = not_normalized/np.sum(not_normalized, axis = 1, keepdims=True)
        
class Loss:
    def calculate(self, y_pred, y_true):
        return np.mean(self.forward(y_pred, y_true))
    
class CategoricalCrossEntropy(Loss): #CCE inherits Loss
    def forward(self, y_pred, y_true):
        #Clip y_pred
        y_pred_clip = np.clip(y_pred, 1e-7, 1 - 1e-7)
        if len(y_true.shape) == 1: #Case 1: Sparse format [0,1,1,2]
            return -np.log(y_pred_clip[range(len(y_pred_clip)), y_true])
        elif len(y_true.shape) == 2: #Case 2: One Hot Encoding of Output
            return -np.log(np.sum(y_pred_clip*y_true, axis = 1)) #Element-wise multiplication
        #Note you are returning negative log likelihood matrix
    def backward(self, dvalues, y_true):
        samples = len(dvalues)
        labels = len(dvalues[0])
    
        #If class labels are sparse, convert to one hot encoded
        if len(y_true.shape) == 1:
            y_true = np.eye(labels)[y_true]
        
        self.dinputs = - y_true/dvalues         #Gradient Calculation
        self.dinputs = self.dinputs/samples     #Normalized with number of samples
        
class Activation_Softmax_CategoricalCrossEntropy:
    def __init__(self):
        self.loss = CategoricalCrossEntropy()
        self.activation = Activation_Softmax()
        
    def forward(self, inputs, y_true):
        self.activation.forward(inputs)
        self.outputs = self.activation.outputs
        return self.loss.calculate(self.outputs, y_true)
    
    def backward(self, dvalues, y_true):
        samples = len(dvalues)
        
        #Convert one-hot encoded y_true to sparse form
        if len(y_true.shape) == 2:
            y_true = np.argmax(y_true, axis = 1)
        
        self.dinputs = dvalues.copy()
        self.dinputs[range(samples), y_true] -= 1
        
        #Normalize this
        self.dinputs = self.dinputs/samples
    
class GradientDescent:
    def __init__(self, learning_rate = 1.0, decay = 0.):
        self.learning_rate = learning_rate
        self.current_learning_rate = learning_rate
        self.decay = decay
        self.iterations = 0
        #Keeping track of current learning rate, alpha0 (initial lr), iterations and decay value
    
    def pre_update_params(self):
        #This method is to be called before update any parameters; it updates the lr with the decay value
        if self.decay:
            self.current_learning_rate = (self.learning_rate) / (1.0 + (self.decay)*(self.iterations))
    
    def update_params(self, layer):
        layer.weights += -(self.current_learning_rate*layer.dweights)
        layer.biases += -(self.current_learning_rate*layer.dbiases)
        
    def post_update_params(self):
        #This method is to be called after update of any parameters; it updates iterations
        self.iterations += 1

# %% [markdown]
# ### Coding forward and backward pass with learning rate decay and gradient descent

# %%
X, y = spiral_data(samples = 100, classes = 3)

dense1 = Layer_Dense(2, 64)
activation1 = Activation_ReLU()
dense2 = Layer_Dense(64, 3)
loss_activation = Activation_Softmax_CategoricalCrossEntropy()
optimizer = GradientDescent(decay=1e-3)

for epoch in range(10000):
    dense1.forward(X)
    activation1.forward(dense1.outputs)
    dense2.forward(activation1.outputs)
    loss = loss_activation.forward(dense2.outputs, y)
    y_pred = np.argmax(loss_activation.outputs, axis = 1)
    
    if len(y.shape) == 2:
        y_true = np.argmax(y, axis = 1)
    else:
        y_true = y
    accuracy = np.mean(y_true == y_pred)
    
    if (epoch+1)% 100 == 0:
        print(f"Epoch: {epoch+1}\tAccuracy: {accuracy:.3f}\tLoss:{loss:.3f}\tLearning Rate:{optimizer.current_learning_rate:.5f}")
    
    loss_activation.backward(loss_activation.outputs,y_true)
    dense2.backward(loss_activation.dinputs)
    activation1.backward(dense2.dinputs)
    dense1.backward(activation1.dinputs)

    optimizer.pre_update_params()
    optimizer.update_params(dense1)
    optimizer.update_params(dense2)
    optimizer.post_update_params()
# Out:
# Epoch: 100	Accuracy: 0.453	Loss:1.059	Learning Rate:0.91075
# Epoch: 200	Accuracy: 0.473	Loss:1.053	Learning Rate:0.83472
# Epoch: 300	Accuracy: 0.463	Loss:1.052	Learning Rate:0.77042
# Epoch: 400	Accuracy: 0.463	Loss:1.052	Learning Rate:0.71531
# Epoch: 500	Accuracy: 0.457	Loss:1.051	Learning Rate:0.66756
# Epoch: 600	Accuracy: 0.453	Loss:1.051	Learning Rate:0.62578
# Epoch: 700	Accuracy: 0.450	Loss:1.050	Learning Rate:0.58893
# Epoch: 800	Accuracy: 0.450	Loss:1.049	Learning Rate:0.55617
# Epoch: 900	Accuracy: 0.453	Loss:1.049	Learning Rate:0.52687
# Epoch: 1000	Accuracy: 0.457	Loss:1.048	Learning Rate:0.50050
# Epoch: 1100	Accuracy: 0.460	Loss:1.047	Learning Rate:0.47664
# Epoch: 1200	Accuracy: 0.470	Loss:1.046	Learning Rate:0.45496
# Epoch: 1300	Accuracy: 0.473	Loss:1.045	Learning Rate:0.43516
# Epoch: 1400	Accuracy: 0.483	Loss:1.044	Learning Rate:0.41701
# Epoch: 1500	Accuracy: 0.483	Loss:1.043	Learning Rate:0.40032
# Epoch: 1600	Accuracy: 0.483	Loss:1.041	Learning Rate:0.38491
# Epoch: 1700	Accuracy: 0.487	Loss:1.040	Learning Rate:0.37064
# Epoch: 1800	Accuracy: 0.493	Loss:1.038	Learning Rate:0.35740
# Epoch: 1900	Accuracy: 0.500	Loss:1.037	Learning Rate:0.34507
# Epoch: 2000	Accuracy: 0.507	Loss:1.035	Learning Rate:0.33356
# Epoch: 2100	Accuracy: 0.493	Loss:1.033	Learning Rate:0.32279
# Epoch: 2200	Accuracy: 0.493	Loss:1.031	Learning Rate:0.31270
# Epoch: 2300	Accuracy: 0.500	Loss:1.029	Learning Rate:0.30321
# Epoch: 2400	Accuracy: 0.500	Loss:1.027	Learning Rate:0.29429
# Epoch: 2500	Accuracy: 0.497	Loss:1.025	Learning Rate:0.28588
# Epoch: 2600	Accuracy: 0.500	Loss:1.023	Learning Rate:0.27793
# Epoch: 2700	Accuracy: 0.497	Loss:1.021	Learning Rate:0.27042
# Epoch: 2800	Accuracy: 0.497	Loss:1.018	Learning Rate:0.26330
# Epoch: 6500	Accuracy: 0.580	Loss:0.899	Learning Rate:0.13337
# Epoch: 6600	Accuracy: 0.597	Loss:0.895	Learning Rate:0.13161
# Epoch: 6700	Accuracy: 0.603	Loss:0.891	Learning Rate:0.12990
# Epoch: 6800	Accuracy: 0.607	Loss:0.887	Learning Rate:0.12824
# Epoch: 6900	Accuracy: 0.607	Loss:0.884	Learning Rate:0.12661
# Epoch: 7000	Accuracy: 0.607	Loss:0.880	Learning Rate:0.12503
# Epoch: 7100	Accuracy: 0.613	Loss:0.876	Learning Rate:0.12349
# Epoch: 7200	Accuracy: 0.630	Loss:0.872	Learning Rate:0.12198
# Epoch: 7300	Accuracy: 0.637	Loss:0.868	Learning Rate:0.12051
# Epoch: 7400	Accuracy: 0.640	Loss:0.864	Learning Rate:0.11908
# Epoch: 7500	Accuracy: 0.650	Loss:0.860	Learning Rate:0.11767
# Epoch: 7600	Accuracy: 0.657	Loss:0.856	Learning Rate:0.11631
# Epoch: 7700	Accuracy: 0.657	Loss:0.853	Learning Rate:0.11497
# Epoch: 7800	Accuracy: 0.663	Loss:0.849	Learning Rate:0.11366
# Epoch: 7900	Accuracy: 0.663	Loss:0.846	Learning Rate:0.11238
# Epoch: 8000	Accuracy: 0.657	Loss:0.842	Learning Rate:0.11114
# Epoch: 8100	Accuracy: 0.657	Loss:0.839	Learning Rate:0.10991
# Epoch: 8200	Accuracy: 0.657	Loss:0.835	Learning Rate:0.10872
# Epoch: 8300	Accuracy: 0.657	Loss:0.832	Learning Rate:0.10755
# Epoch: 8400	Accuracy: 0.657	Loss:0.829	Learning Rate:0.10641
# Epoch: 8500	Accuracy: 0.657	Loss:0.825	Learning Rate:0.10529
# Epoch: 8600	Accuracy: 0.653	Loss:0.822	Learning Rate:0.10419
# Epoch: 8700	Accuracy: 0.657	Loss:0.819	Learning Rate:0.10311
# Epoch: 8800	Accuracy: 0.657	Loss:0.816	Learning Rate:0.10206
# Epoch: 8900	Accuracy: 0.660	Loss:0.813	Learning Rate:0.10103
# Epoch: 9000	Accuracy: 0.660	Loss:0.810	Learning Rate:0.10002
# Epoch: 9100	Accuracy: 0.663	Loss:0.808	Learning Rate:0.09903
# Epoch: 9200	Accuracy: 0.663	Loss:0.805	Learning Rate:0.09806
# Epoch: 9300	Accuracy: 0.663	Loss:0.802	Learning Rate:0.09711
# Epoch: 9400	Accuracy: 0.663	Loss:0.799	Learning Rate:0.09617
# Epoch: 9500	Accuracy: 0.663	Loss:0.797	Learning Rate:0.09526
# Epoch: 9600	Accuracy: 0.663	Loss:0.794	Learning Rate:0.09436
# Epoch: 9700	Accuracy: 0.667	Loss:0.792	Learning Rate:0.09348
# Epoch: 9800	Accuracy: 0.667	Loss:0.789	Learning Rate:0.09261
# Epoch: 9900	Accuracy: 0.670	Loss:0.787	Learning Rate:0.09176
# Epoch: 10000	Accuracy: 0.670	Loss:0.785	Learning Rate:0.09093
